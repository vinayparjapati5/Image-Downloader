# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayparjapati5/Image-Downloader/blob/main/ImageDownloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ## **Mini Project : Image Downloader**
# ---

# %% [markdown]
# ---
# ### 1. Install the bing_images_downloader package
# ---

# %%
# !pip install bing-image-downloader &> /dev/null
print("Bing Images Downloader installed successfully......")
# Out:
# Bing Images Downloader installed successfully......

# %% [markdown]
# ---
# ### 2. Import Downloader & Download Images
# ---

# %%
from bing_image_downloader import downloader

downloader.download("bird", limit=100)
# Out:
# [%] Downloading Images to /content/dataset/bird
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.freshboo.com/wp-content/uploads/2014/11/eastern-bluebird-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://i.stack.imgur.com/e3Rua.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.birdsandblooms.com/wp-content/uploads/2016/05/bluebird.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.borealbirds.org/sites/default/files/bird_images/eastern-kingbird.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://nzbirdsonline.org.nz/sites/all/files/1200543tui.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://1.bp.blogspot.com/-USsF2WR287s/TqvSzg0HTaI/AAAAAAAACQA/scBUg6SlLOc/s1600/cendrawasih-flying.jpg
# [%] File Downloaded !
#
# ...

# %% [markdown]
# ---
# ### 3. Download complete file in your Google drive
# ---

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

# Path to the folder you want to download
folder_path = '/content/dataset/bird'

# Name for the output zip file
zip_filename = '/content/drive/MyDrive/output_folder.zip'

# Create a zip file of the folder
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            zipf.write(file_path, arcname=os.path.relpath(file_path, folder_path))
